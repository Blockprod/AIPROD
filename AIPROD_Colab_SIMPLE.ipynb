# %% [markdown]
# # AIPROD Phase 1 Training - Google Colab (SIMPLE)
# ## Version Simplifiée et Robuste
#
# **IMPORTANT**: Avant de commencer, change le runtime:
# - Runtime → Change runtime type → GPU (T4 ou L4)

# %% [markdown]
# ## Étape 1: Monter Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Étape 2: Cloner via Git (Kaggle version)

# %%
import subprocess
import os

os.chdir('/kaggle/working')

print("⏳ Clonage du repository...")
result = subprocess.run(
    ['git', 'clone', '--depth', '1', 'https://github.com/Blockprod/AIPROD.git'],
    capture_output=True,
    text=True,
    timeout=120
)

if result.returncode == 0:
    print("✓ Repository cloné!")
    os.system('ls -la /kaggle/working/AIPROD | head -15')
else:
    print(f"Erreur: {result.stderr[:200]}")

# %% [markdown]
# ## Étape 3: Vérifier le repository

# %%
import os
if os.path.exists('/content/AIPROD/requirements.txt'):
    print("✓ Repository prêt!")
    print("✓ requirements.txt trouvé")
    os.system('ls -la /content/AIPROD | head -15')
else:
    print("⚠️ ERREUR: requirements.txt non trouvé")
    print("Réessaie la cellule précédente")

# %% [markdown]
# ## Étape 4: Installer les dépendances PyTorch + requirements

# %%
# !pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %%
# !cd /content/AIPROD && pip install -q -r requirements.txt

# %% [markdown]
# ## Étape 5: Vérifier le GPU

# %%
import torch
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")

# %% [markdown]
# ## Étape 6: Créer dossier checkpoints dans Google Drive

# %%
import os
os.makedirs('/content/drive/MyDrive/AIPROD_checkpoints', exist_ok=True)
print("✓ Dossier créé")

# %% [markdown]
# ## Étape 7: LANCER L'ENTRAÎNEMENT PHASE 1 🚀

# %%
# %cd /content/AIPROD
# !python packages/aiprod-core/src/training/train.py --start-phase 1 --max-epochs 10

# %% [markdown]
# ## Étape 8: Sauvegarder les checkpoints (après training)

# %%
# !cp -v /content/AIPROD/checkpoints/* /content/drive/MyDrive/AIPROD_checkpoints/ 2>/dev/null || echo "Aucun checkpoint à copier"
