# %% [markdown]
# # AIPROD Phase 1 Training - Google Colab
# ## Version Ultra-Simple avec Git Clone
#
# **IMPORTANT**: Avant de commencer:
# 1. Runtime → Change runtime type → GPU (T4 ou L4)
# 2. Exécute chaque cellule dans l'ordre

# %% [markdown]
# ## 1️⃣ Monter Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
print('✓ Google Drive monté')

# %% [markdown]
# ## 2️⃣ Cloner le repository directement

# %%
# !cd /content && rm -rf AIPROD && git clone --depth 1 https://github.com/Blockprod/AIPROD.git && cd AIPROD && ls -la | head -20

# %% [markdown]
# ## 3️⃣ Installer PyTorch (CUDA 11.8)

# %%
# !pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
print('✓ PyTorch installé')

# %% [markdown]
# ## 4️⃣ Installer les dépendances du projet

# %%
# !cd /content/AIPROD && pip install -q -r requirements.txt
print('✓ Requirements installés')

# %% [markdown]
# ## 5️⃣ Vérifier le GPU

# %%
import torch
print(f'PyTorch version: {torch.__version__}')
print(f'CUDA disponible: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
    print(f'VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')
else:
    print('⚠️ GPU NON DÉTECTÉ! Vérifie Runtime → Change runtime type → GPU')

# %% [markdown]
# ## 6️⃣ Créer dossier checkpoints dans Google Drive

# %%
import os
os.makedirs('/content/drive/MyDrive/AIPROD_checkpoints', exist_ok=True)
print('✓ Dossier créé: /content/drive/MyDrive/AIPROD_checkpoints')

# %% [markdown]
# ## 🚀 7️⃣ LANCER L'ENTRAÎNEMENT PHASE 1

# %%
# %cd /content/AIPROD
# !python packages/aiprod-core/src/training/train.py --start-phase 1 --max-epochs 10

# %% [markdown]
# ## 8️⃣ Sauvegarder les checkpoints dans Google Drive

# %%
import os
import shutil

src = '/content/AIPROD/checkpoints'
dst = '/content/drive/MyDrive/AIPROD_checkpoints'

if os.path.exists(src) and os.listdir(src):
    for f in os.listdir(src):
        shutil.copy2(os.path.join(src, f), os.path.join(dst, f))
        print(f'✓ Copié: {f}')
    print('\n✅ Checkpoints sauvegardés!')
else:
    print('Aucun checkpoint à sauvegarder')

# %% [markdown]
# ## ✅ C'est fini!
#
# Si tu veux continuer avec Phase 2 après:
# ```python
# !python packages/aiprod-core/src/training/train.py --start-phase 2
# ```
